# %% [markdown]
# ![dmriveroecognitiveclassdataanalysiswithpython.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![dmriveroecognitiveclassdatavisualizationwithpython.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![dmriveroecognitiveclasspython101fordatascience.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![dmriveroecognitiveclassaapplieddatadciencewithpython.jpg](data:image/jpeg;base64,...)
